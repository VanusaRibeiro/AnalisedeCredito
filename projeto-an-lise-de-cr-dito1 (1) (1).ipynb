# %% [markdown]
# A finalidade desse projeto é avaliar uma base de cartão de crédito
# com o objetivo de identificar os bons e maus pagadores.
# Temos uma varável chamada **default**- que será usada para identificar o mal pagador (True=mal, False=bom).<br>
# Iniciamos o projeto da seguinte forma:<br>
# 1.   importando as bibliotecas<br>
# 2.   Verificando clientes adimplentes e inadimplentes<br>
# 3.   Conhecendo as estruturas dos dados e colunas<br>
# 4.   Atributos categóricos e númericos<br>
# 5.   Limpeza de dados e Visualização de dados
#
# Após análise, foi verificado que a proporção de clientes adimplentes está mais elevada que a proporção de clientes inadimplentes.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/Credscore/projeto_an_lise_de_cr_dito_(3).ipynb
# /kaggle/input/fonteproj/BALLAD ITALIC.otf
# /kaggle/input/imgemproj/img.png

# %%
   
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
from termcolor import colored


image = Image.open(r'/kaggle/input/imgemproj/img.png')  
image=image.resize((1000,200))
  
draw = ImageDraw.Draw(image) 
  
font = ImageFont.truetype(r'/kaggle/input/fonteproj/BALLAD ITALIC.otf', 23) 
  
text = 'ANÁLISE DE CRÉDITO'

  
draw.text((400, 70), text, font = font) 

 
#image_cinza=image.convert(mode="L")

image
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x200>

# %% [markdown]
# `
#
# > **Clientes Adimplentes e Inadimplentes**

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/develop/dataset/credito.csv',na_values='na'
)
df.head(n=10)
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
# 5  713061558        0     44    M            2             mestrado
# 6  810347208        0     51    M            4                  NaN
# 7  818906208        0     32    M            0         ensino medio
# 8  710930508        0     37    M            3  sem educacao formal
# 9  719661558        0     48    M            2             mestrado
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
# 5       casado     $40K - $60K        blue                       36
# 6       casado         $120K +        gold                       46
# 7          NaN     $60K - $80K      silver                       27
# 8     solteiro     $60K - $80K        blue                       36
# 9     solteiro    $80K - $120K        blue                       36
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# 1             6              2                  1       8.256,96
# 2             4              0                  1       3.418,56
# 3             3              1                  4       3.313,03
# 4             5              0                  1       4.716,22
# 5             3              2                  1       4.010,69
# 6             6              3                  1      34.516,72
# 7             2              2                  2      29.081,49
# 8             5              0                  2      22.352,50
# 9             6              3                  3      11.656,41
#
#   valor_transacoes_12m  qtd_transacoes_12m
# 0             1.144,90                  42
# 1             1.291,45                  33
# 2             1.887,72                  20
# 3             1.171,56                  20
# 4               816,08                  28
# 5             1.088,07                  24
# 6             1.330,87                  31
# 7             1.538,32                  36
# 8             1.350,14                  24
# 9             1.441,73                  32

# %% [markdown]
# > **Conhecendo a estrutura dos dados:**
#
# > df.shape - retorna uma tupla (qtd linhas, qtd colunas)

# %%
df.shape
# Out:
# (10127, 16)

# %%
df[df['default'] == 0].shape

df[df['default'] == 1].shape

qtd_total, _ = df.shape
qtd_adimplentes, _ = df[df['default'] == 0].shape
qtd_inadimplentes, _ = df[df['default'] == 1].shape

print(f"A proporcão clientes adimplentes é de " + \
 f"{round(100 * qtd_adimplentes / qtd_total, 2)}%"
 )
print(f"A proporcão clientes inadimplentes é de " + \
 f"{round(100 * qtd_inadimplentes / qtd_total, 2)}%"
 )
# Out:
# A proporcão clientes adimplentes é de 83.93%
# A proporcão clientes inadimplentes é de 16.07%

# %%
df[df['default'] == 0].shape
# Out:
# (8500, 16)

# %%
df[df['default'] == 1].shape
# Out:
# (1627, 16)

# %%
df.head(n=5)
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# 1             6              2                  1       8.256,96
# 2             4              0                  1       3.418,56
# 3             3              1                  4       3.313,03
# 4             5              0                  1       4.716,22
#
#   valor_transacoes_12m  qtd_transacoes_12m
# 0             1.144,90                  42
# 1             1.291,45                  33
# 2             1.887,72                  20
# 3             1.171,56                  20
# 4               816,08                  28

# %% [markdown]
# > **Colunas e seus respectivos tipos de dados**

# %%
df.dtypes
# Out:
# id                          int64
# default                     int64
# idade                       int64
# sexo                       object
# dependentes                 int64
# escolaridade               object
# estado_civil               object
# salario_anual              object
# tipo_cartao                object
# meses_de_relacionamento     int64
# qtd_produtos                int64
# iteracoes_12m               int64
# meses_inativo_12m           int64
# limite_credito             object
# valor_transacoes_12m       object
# qtd_transacoes_12m          int64
# dtype: object

# %% [markdown]
# > **Conhecendo os atributos categóricos**

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                       count unique             top  freq
# sexo                  10127      2               F  5358
# escolaridade           8608      5        mestrado  3128
# estado_civil           9378      3          casado  4687
# salario_anual          9015      5  menos que $40K  3561
# tipo_cartao           10127      4            blue  9436
# limite_credito        10127   9272        1.438,21    11
# valor_transacoes_12m  10127  10035        3.851,51     3

# %% [markdown]
# > **conhecendo os atributos numéricos**

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count       mean        std   min   25%   50%  \
# default                  10127.0   0.160660   0.367235   0.0   0.0   0.0
# idade                    10127.0  46.325960   8.016814  26.0  41.0  46.0
# dependentes              10127.0   2.346203   1.298908   0.0   1.0   2.0
# meses_de_relacionamento  10127.0  35.928409   7.986416  13.0  31.0  36.0
# qtd_produtos             10127.0   3.812580   1.554408   1.0   3.0   4.0
# iteracoes_12m            10127.0   2.455317   1.106225   0.0   2.0   2.0
# meses_inativo_12m        10127.0   2.341167   1.010622   0.0   2.0   2.0
# qtd_transacoes_12m       10127.0  64.858695  23.472570  10.0  45.0  67.0
#
#                           75%    max
# default                   0.0    1.0
# idade                    52.0   73.0
# dependentes               3.0    5.0
# meses_de_relacionamento  40.0   56.0
# qtd_produtos              5.0    6.0
# iteracoes_12m             3.0    6.0
# meses_inativo_12m         3.0    6.0
# qtd_transacoes_12m       81.0  139.0

# %% [markdown]
# > **Verificando dados faltantes**

# %%
df.head()
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# 1             6              2                  1       8.256,96
# 2             4              0                  1       3.418,56
# 3             3              1                  4       3.313,03
# 4             5              0                  1       4.716,22
#
#   valor_transacoes_12m  qtd_transacoes_12m
# 0             1.144,90                  42
# 1             1.291,45                  33
# 2             1.887,72                  20
# 3             1.171,56                  20
# 4               816,08                  28

# %%
df.isna().any()
# Out:
# id                         False
# default                    False
# idade                      False
# sexo                       False
# dependentes                False
# escolaridade                True
# estado_civil                True
# salario_anual               True
# tipo_cartao                False
# meses_de_relacionamento    False
# qtd_produtos               False
# iteracoes_12m              False
# meses_inativo_12m          False
# limite_credito             False
# valor_transacoes_12m       False
# qtd_transacoes_12m         False
# dtype: bool

# %% [markdown]
# > **levantando estatística dos dados faltantes**

# %%
def stats_dados_faltantes(df: pd.DataFrame) -> None:
 stats_dados_faltantes = []
 for col in df.columns:
    if df[col].isna().any():
       qtd, _ = df[df[col].isna()].shape
       total, _ = df.shape
       dict_dados_faltantes = {col:
       {
        'quantidade': qtd,
        "porcentagem": round(100 * qtd/total, 2)
        }
        }
 stats_dados_faltantes.append(dict_dados_faltantes)
 for stat in stats_dados_faltantes:
   print(stat)

stats_dados_faltantes(df=df)

stats_dados_faltantes(df=df[df['default'] == 0])

stats_dados_faltantes(df=df[df['default'] == 1])
# Out:
# {'salario_anual': {'quantidade': 1112, 'porcentagem': 10.98}}
# {'salario_anual': {'quantidade': 925, 'porcentagem': 10.88}}
# {'salario_anual': {'quantidade': 187, 'porcentagem': 11.49}}

# %% [markdown]
# >**Transformação e limpeza:**<br>
#  corrigindo schema:

# %%
df[['limite_credito', 'valor_transacoes_12m']].dtypes
# Out:
# limite_credito          object
# valor_transacoes_12m    object
# dtype: object

# %%
df[['limite_credito', 'valor_transacoes_12m']].head(n=5)
# Out:
#   limite_credito valor_transacoes_12m
# 0      12.691,51             1.144,90
# 1       8.256,96             1.291,45
# 2       3.418,56             1.887,72
# 3       3.313,03             1.171,56
# 4       4.716,22               816,08

# %%
fn = lambda valor: float(valor.replace(".", "").replace(",", "."))
valores_originais = [
 '12.691,51',
 '8.256,96',
 '3.418,56',
 '3.313,03',
 '4.716,22'
]

valores_limpos = list(map(fn, valores_originais))
#print(valores_originais)
print(valores_limpos)
# Out:
# [12691.51, 8256.96, 3418.56, 3313.03, 4716.22]

# %% [markdown]
# > **Limpando os dados:<br>**
#
# > Com a função lambda de limpeza pronta, basta aplica-la nas colunas de interesse.
#
# >Vamos descrever novamente o schema:
#
# > Atributos categóricos.
#
# > Atributos numéricos.
#
# >  Remoção de dados faltantes
#
# >Como o pandas está ciente do que é um dados faltante, a remoção das linhas problemáticas é
# trivial.<br>Vamos analisar a estrutura dos dados novamente.

# %%
valores_limpos = list(map(fn, valores_originais))
print(valores_originais)
print(valores_limpos)
# Out:
# ['12.691,51', '8.256,96', '3.418,56', '3.313,03', '4.716,22']
# [12691.51, 8256.96, 3418.56, 3313.03, 4716.22]

# %%
df['valor_transacoes_12m']
# Out:
# 0         1.144,90
# 1         1.291,45
# 2         1.887,72
# 3         1.171,56
# 4           816,08
#            ...
# 10122    15.476,26
# 10123     8.764,88
# 10124    10.291,78
# 10125     8.395,62
# 10126    10.294,96
# Name: valor_transacoes_12m, Length: 10127, dtype: object

# %%
df['limite_credito']
# Out:
# 0        12.691,51
# 1         8.256,96
# 2         3.418,56
# 3         3.313,03
# 4         4.716,22
#            ...
# 10122     4.003,91
# 10123     4.277,04
# 10124     5.409,16
# 10125     5.281,84
# 10126    10.388,80
# Name: limite_credito, Length: 10127, dtype: object

# %%
df.dtypes
# Out:
# id                          int64
# default                     int64
# idade                       int64
# sexo                       object
# dependentes                 int64
# escolaridade               object
# estado_civil               object
# salario_anual              object
# tipo_cartao                object
# meses_de_relacionamento     int64
# qtd_produtos                int64
# iteracoes_12m               int64
# meses_inativo_12m           int64
# limite_credito             object
# valor_transacoes_12m       object
# qtd_transacoes_12m          int64
# dtype: object

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                       count unique             top  freq
# sexo                  10127      2               F  5358
# escolaridade           8608      5        mestrado  3128
# estado_civil           9378      3          casado  4687
# salario_anual          9015      5  menos que $40K  3561
# tipo_cartao           10127      4            blue  9436
# limite_credito        10127   9272        1.438,21    11
# valor_transacoes_12m  10127  10035        3.851,51     3

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count       mean        std   min   25%   50%  \
# default                  10127.0   0.160660   0.367235   0.0   0.0   0.0
# idade                    10127.0  46.325960   8.016814  26.0  41.0  46.0
# dependentes              10127.0   2.346203   1.298908   0.0   1.0   2.0
# meses_de_relacionamento  10127.0  35.928409   7.986416  13.0  31.0  36.0
# qtd_produtos             10127.0   3.812580   1.554408   1.0   3.0   4.0
# iteracoes_12m            10127.0   2.455317   1.106225   0.0   2.0   2.0
# meses_inativo_12m        10127.0   2.341167   1.010622   0.0   2.0   2.0
# qtd_transacoes_12m       10127.0  64.858695  23.472570  10.0  45.0  67.0
#
#                           75%    max
# default                   0.0    1.0
# idade                    52.0   73.0
# dependentes               3.0    5.0
# meses_de_relacionamento  40.0   56.0
# qtd_produtos              5.0    6.0
# iteracoes_12m             3.0    6.0
# meses_inativo_12m         3.0    6.0
# qtd_transacoes_12m       81.0  139.0

# %%
df.dropna(inplace=True)
#Analisando a estrutura novamente
df.shape

df[df['default'] == 0].shape

df[df['default'] == 1].shape

qtd_total_novo, _ = df.shape
qtd_adimplentes_novo, _ = df[df['default'] == 0].shape
qtd_inadimplentes_novo, _ = df[df['default'] == 1].shape

print(f"A proporcão adimplentes ativos é de " + \
 f"{round(100 * qtd_adimplentes / qtd_total, 2)}%"
 )
print(f"A nova proporcão de clientes adimplentes é de " + \
 f"{round(100 * qtd_adimplentes_novo / qtd_total_novo, 2)}%"
 )
print("")
print(f"A proporcão clientes inadimplentes é de " + \
 f"{round(100 * qtd_inadimplentes / qtd_total, 2)}%"
 )
print(f"A nova proporcão de clientes inadimplentes é de " + \
 f"{round(100 * qtd_inadimplentes_novo / qtd_total_novo, 2)}%"
 )
# Out:
# A proporcão adimplentes ativos é de 83.93%
# A nova proporcão de clientes adimplentes é de 84.28%
#
# A proporcão clientes inadimplentes é de 16.07%
# A nova proporcão de clientes inadimplentes é de 15.72%

# %% [markdown]
# > Dados do Projeto

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")

df_adimplente = df[df['default'] == 0]

df_inadimplente = df[df['default'] == 1]

# %% [markdown]
# ><b>**Visualização categórica**

# %% [markdown]
# >**Visualizando a relação entre a variável resposta default com os atributos categóricos.**

# %%
#Escolaridade
print(f"A proporcão clientes adimplentes é de " + \
f"{round(100 * qtd_adimplentes_novo / qtd_total_novo, 2)}%"
 )

print("")
print(f"A proporcão clientes inadimplentes é de " + \
f"{round(100 * qtd_inadimplentes / qtd_total, 2)}%"
 )
print(f"A nova proporcão de clientes inadimplentes é de " + \
f"{round(100 * qtd_inadimplentes_novo / qtd_total_novo, 2)}%"
 )

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")

df_adimplente = df[df['default'] == 0]

df_inadimplente = df[df['default'] == 1]

df.select_dtypes('object').head(n=5)

coluna = 'escolaridade'
titulos = [
 'Escolaridade dos Clientes',
 'Escolaridade dos Clientes Adimplentes',
 'Escolaridade dos Clientes Inadimplentes'
]
eixo = 0
max_y = 3
max = df.select_dtypes('object').describe()[coluna]['freq'] * 1.1
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)
for dataframe in [df, df_adimplente, df_inadimplente]:
 df_to_plot = dataframe[coluna].value_counts().to_frame()
 df_to_plot.rename(columns={coluna: 'frequencia_absoluta'}, inplace=True)
 df_to_plot[coluna] = df_to_plot.index
 df_to_plot.sort_values(by=[coluna], inplace=True)
 df_to_plot.sort_values(by=[coluna])
 f = sns.barplot(
 x=df_to_plot[coluna],
 y=df_to_plot['frequencia_absoluta'],
 ax=eixos[eixo]
 )
 f.set(
 title=titulos[eixo],
 xlabel=coluna.capitalize(),
 ylabel='Frequência Absoluta'
 )
 f.set_xticklabels(labels=f.get_xticklabels(), rotation=90)
 _, max_y_f = f.get_ylim()
 max_y = max_y_f if max_y_f > max_y else max_y
 f.set(ylim=(0, max_y))
 eixo += 1
figura.show()
# Out:
# A proporcão clientes adimplentes é de 84.28%
#
# A proporcão clientes inadimplentes é de 16.07%
# A nova proporcão de clientes inadimplentes é de 15.72%

# %%
#Salário Anual
coluna = 'salario_anual'
titulos = [
 'Salário Anual dos Clientes',
 'Salário Anual dos Clientes Adimplentes',
 'Salário Anual dos Clientes Inadimplentes'
]
eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)
for dataframe in [df, df_adimplente, df_inadimplente]:
 df_to_plot = dataframe[coluna].value_counts().to_frame()
 df_to_plot.rename(columns={coluna: 'frequencia_absoluta'}, inplace=True)
 df_to_plot[coluna] = df_to_plot.index
 df_to_plot.reset_index(inplace=True, drop=True)
 df_to_plot.sort_values(by=[coluna], inplace=True)
 f = sns.barplot(
 x=df_to_plot[coluna],
 y=df_to_plot['frequencia_absoluta'],
 ax=eixos[eixo]
 )
 f.set(
 title=titulos[eixo],
 xlabel=coluna.capitalize(),
 ylabel='Frequência Absoluta'
 )
 f.set_xticklabels(labels=f.get_xticklabels(), rotation=90)
 _, max_y_f = f.get_ylim()
 max_y = max_y_f if max_y_f > max_y else max_y
 f.set(ylim=(0, max_y))
 eixo += 1
figura.show()

# %% [markdown]
# > ** Visualizações numéricas**

# %% [markdown]
# > Visualizando a relação entre a variável resposta default com os atributos numéricos:
#
# > Quantidade de Transações nos Últimos 12 Meses:

# %%
#Valor das Transações nos Últimos 12 Meses:

coluna = 'valor_transacoes_12m'
titulos = [
 'Valor das Transações no Último Ano',
 'Valor das Transações no Último Ano de Adimplentes',
 'Valor das Transações no Último Ano de Inadimplentes'
]
eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)
for dataframe in [df, df_adimplente, df_inadimplente]:
 f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
 f.set(
 title=titulos[eixo],
xlabel=coluna.capitalize(),
 ylabel='Frequência Absoluta'
 )
 _, max_y_f = f.get_ylim()
 max_y = max_y_f if max_y_f > max_y else max_y
 f.set(ylim=(0, max_y))
 eixo += 1
figura.show()

# %%
#Valor de Transações nos Últimos 12 Meses x Quantidade de Transações nos Últimos 12 Meses
coluna = 'valor_transacoes_12m'
titulos = [
 'valor_transacoes_12m',
 'qtd_transacoes_12m',
 'Valor das Transações no Último Ano de Inadimplentes'
]
eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)
f = sns.relplot(
 x='valor_transacoes_12m',
 y='qtd_transacoes_12m',
 data=df,
 hue='default'
)
_ = f.set(
 title='Relação entre Valor e Quantidade de Transações no Último Ano',
 xlabel='Valor das Transações no Último Ano',
 ylabel='Quantidade das Transações no Último Ano'
 )
figura.show()
